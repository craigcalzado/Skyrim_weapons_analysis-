# %%
import acquire

# %%
df = acquire.acquire_weapons()
# Out:
# Using cached file...

# %%
df.head()
# Out:
#                       Name  Damage  Weight  Gold              Upgrade  \
# 0  Ancient Nord Battle Axe      18    22.0    28          Steel Ingot
# 1        Daedric Battleaxe      25    27.0  2750          Ebony Ingot
# 2    Dragonbone Battleaxe       26    30.0  3000          Dragon Bone
# 3     Drainblood Battleaxe      21     5.0   266                  NaN
# 4        Dwarven Battleaxe      20    23.0   300  Dwarven Metal Ingot
#
#       Perk       Type    Category  Speed
# 0    Steel  Battleaxe  Two-Handed    NaN
# 1  Daedric  Battleaxe  Two-Handed    NaN
# 2   Dragon  Battleaxe  Two-Handed    NaN
# 3        -  Battleaxe  Two-Handed    NaN
# 4  Dwarven  Battleaxe  Two-Handed    NaN

# %%
# make all columns lowercase
df.columns = df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      293 non-null    object
#  1   damage    293 non-null    int64
#  2   weight    293 non-null    float64
#  3   gold      293 non-null    int64
#  4   upgrade   232 non-null    object
#  5   perk      251 non-null    object
#  6   type      293 non-null    object
#  7   category  293 non-null    object
#  8   speed     39 non-null     float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 20.7+ KB

# %%
# view only the rows with NaN in the upgrade column
df.loc[df['upgrade'].isnull()]
# Out:
#                                 name  damage  weight  gold upgrade perk  \
# 3               Drainblood Battleaxe      21     5.0   266     NaN    -
# 8                     Headsman's Axe      17    11.0    15     NaN    -
# 19             The Woodsman's Friend      17    20.0    28     NaN    -
# 20                  Tsun's Battleaxe      27    36.0  1000     NaN    -
# 21                          Wuuthrad      25    25.0  2000     NaN    -
# ..                               ...     ...     ...   ...     ...  ...
# 288      Exploding Steel Bolt of Ice      10     0.0     5     NaN  NaN
# 289    Exploding Steel Bolt of Shock      10     0.0     5     NaN  NaN
# 290   Exploding Dwarven Bolt of Fire      14     0.0    15     NaN  NaN
# 291    Exploding Dwarven Bolt of Ice      14     0.0    15     NaN  NaN
# 292  Exploding Dwarven Bolt of Shock      14     0.0    15     NaN  NaN
#
#           type    category  speed
# 3    Battleaxe  Two-Handed    NaN
# ...

# %% [markdown]
# It appears that weapons that cannot be upgraded are special weapons.

# %%
# fill all nulls in upgrade column with 'non-upgradeable'.
df.loc[df['upgrade'].isnull(), 'upgrade'] = 'non-upgradeable'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      293 non-null    object
#  1   damage    293 non-null    int64
#  2   weight    293 non-null    float64
#  3   gold      293 non-null    int64
#  4   upgrade   293 non-null    object
#  5   perk      251 non-null    object
#  6   type      293 non-null    object
#  7   category  293 non-null    object
#  8   speed     39 non-null     float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 20.7+ KB

# %%
# unique values in the perk column
df['perk'].unique()
# Out:
# array(['Steel', 'Daedric', 'Dragon', '-', 'Dwarven', 'Ebony', 'Elven',
#        'Glass', 'None', 'Advanced', 'Orcish', '–', nan], dtype=object)

# %%
# look at all rows that are null in perk column
df.loc[df['perk'].isnull()]
# Out:
#                                 name  damage  weight  gold  \
# 154                   Falmer War Axe      11    21.0    82
# 156         Ghorbash's Ancestral Axe       8    11.0    30
# 162                     Iron War Axe       8    11.0    30
# 163     Lunar Iron War Axe (Lvl 2-3)       8    11.0    94
# 164     Lunar Iron War Axe (Lvl 4-5)       8    11.0   128
# 165      Lunar Iron War Axe (Lvl 6+)       8    11.0   163
# 171                  Notched Pickaxe       5    10.0   303
# 175                    Poacher's Axe       5    10.0    32
# 181                             Fork       1     0.5     5
# 182                            Knife       2     0.5     1
# 261               Ancient Nord Arrow      10     0.0     1
# 262       Bloodcursed Elven Arrow DG      16     0.0     6
# 263                    Daedric Arrow      24     0.0     8
# 264              Dragonbone Arrow DG      25     0.0     9
# 265                    Dwarven Arrow      14     0.0     4
# ...

# %%
# drop perk and speed columns
df.drop(['perk', 'speed'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293 entries, 0 to 292
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      293 non-null    object
#  1   damage    293 non-null    int64
#  2   weight    293 non-null    float64
#  3   gold      293 non-null    int64
#  4   upgrade   293 non-null    object
#  5   type      293 non-null    object
#  6   category  293 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 16.1+ KB

# %%
def clean_weapons(df):
    '''This function cleans the weapons dataframe.'''
    # make all columns lowercase
    df.columns = df.columns.str.lower()
    # replace nulls with non-upgradeable
    df.loc[df['upgrade'].isnull(), 'upgrade'] = 'non-upgradeable'
    # drop perk and speed columns
    df.drop(['perk', 'speed'], axis=1, inplace=True)
    return df
